# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhatrilok02/Fretron_Assignment/blob/main/Flights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
1#st method

def plot_multiple_lines():
  N = int(input("Enter the number of Flights: "))
  Flights = []
  for i in range(N):
    line_str = input(f"Enter coordinates for Flight {i+1} (e.g., 1,1 2,4 3,2): ")
    coords = [(int(x), int(y)) for x, y in [pair.split(',') for pair in line_str.split()]]
    Flights.append(coords)

  plt.figure(figsize=(8, 6))

  for i, line in enumerate(Flights):
    xs = [x[0] for x in line]
    ys = [x[1] for x in line]
    plt.plot(xs, ys, linestyle='solid', linewidth=3, marker='o', markerfacecolor='blue', markersize=12)

  plt.xlabel("X-axis")
  plt.ylabel("Y-axis")
  plt.title("Multiple Lines Plot")
  plt.grid(True)
  plt.legend([f'Flight {i+1}' for i in range(N)])
  plt.show()

plot_multiple_lines()
# Out:
# Enter the number of Flights: 3
# Enter coordinates for Flight 1 (e.g., 1,1 2,4 3,2): 1,1 2,2 3,3
# Enter coordinates for Flight 2 (e.g., 1,1 2,4 3,2): 1,1 2,4 3,2
# Enter coordinates for Flight 3 (e.g., 1,1 2,4 3,2): 1,1 4,2 3,4

# %%
#2nd method
import matplotlib.pyplot as plt
import numpy as np

def plot_lines(list_of_lines):
  plt.figure(figsize=(8, 6))

  for i, li in enumerate(list_of_lines):
    xs = [x[0] for x in li]
    ys = [x[1] for x in li]
    plt.plot(xs, ys, linestyle='solid', linewidth=3,
             marker='o', markersize=12, label=f'Line {i+1}')

  plt.xlabel("X-axis")
  plt.ylabel("Y-axis")
  plt.title("Flight routes ")
  plt.grid(True)
  plt.legend()
  plt.show()

# Get user input for the number of lines
N = int(input("Enter the number of lines: "))

# Initialize an empty list to store the lines
list_of_lines = []

# Get coordinates for each line from the user
for i in range(N):
  line = []
  num_points = int(input(f"Enter the number of points for line {i+1}: "))
  for j in range(num_points):
    x = int(input(f"Enter x-coordinate for point {j+1}: "))
    y = int(input(f"Enter y-coordinate for point {j+1}: "))
    line.append((x, y))
  list_of_lines.append(line)

# Plot the lines
plot_lines(list_of_lines)
# Out:
# Enter the number of lines: 3
# Enter the number of points for line 1: 3
# Enter x-coordinate for point 1: 1
# Enter y-coordinate for point 1: 1
# Enter x-coordinate for point 2: 2
# Enter y-coordinate for point 2: 2
# Enter x-coordinate for point 3: 3
# Enter y-coordinate for point 3: 3
# Enter the number of points for line 2: 3
# Enter x-coordinate for point 1: 1
# Enter y-coordinate for point 1: 1
# Enter x-coordinate for point 2: 2
# Enter y-coordinate for point 2: 4
# Enter x-coordinate for point 3: 3
# Enter y-coordinate for point 3: 2
# Enter the number of points for line 3: 3
# Enter x-coordinate for point 1: 1
# Enter y-coordinate for point 1: 1
# Enter x-coordinate for point 2: 4
# Enter y-coordinate for point 2: 2
# Enter x-coordinate for point 3: 3
# Enter y-coordinate for point 3: 4

# %%
import matplotlib.pyplot as plt
import numpy as np

li1 = [(1, 1), (2, 2), (3, 3)]
li2 = [(1, 1), (2, 4), (3, 2)]
li3 = [(1, 1), (4, 2), (3, 4)]

# Plotting
plt.figure(figsize=(8, 6))

for li, color in zip([li1, li2, li3], ['blue', 'red', 'green']):
  xs = [x[0] for x in li]
  ys = [x[1] for x in li]
  plt.plot(xs, ys, color=color, linestyle='solid', linewidth=3,
           marker='o', markerfacecolor='blue', markersize=12)

plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Flight routes ")
plt.grid(True)  # Add a grid if desired
plt.legend(['Flight 1', 'Flight 2', 'Flight 3'])  # Add a legend
plt.show()

# %%
# sample data
li = list(zip(range(1,4), range(4, 7)))

li = [(1, 1), (2, 2), (3, 3)]
li = [(1, 1), (2, 4), (3, 2)]
li = [(1, 1), (4, 2), (3, 4)]

# %%
xs = [x[0] for x in li]
ys = [x[1] for x in li]
plt.plot(xs, ys, color='green', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='blue', markersize=12)
